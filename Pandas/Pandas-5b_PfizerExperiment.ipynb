# %% [markdown]
# <a href="https://colab.research.google.com/github/ramkumar997/Data_Science/blob/main/Pandas/Pandas-5b_PfizerExperiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://colab.research.google.com/drive/1tSQlPfaMMIFGGjfwFYnUF7bIYauBpZdQ?usp=sharing

# %%
# !gdown 173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=173A59xh2mnpmljCCB9bhC4C5eP2IS6qZ
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 6.85MB/s]

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Pfizer_1.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
data.head()
# Out:
#          Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0  15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1  15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2  15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3  15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4  15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
#
#    3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0      NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1      NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2     18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3     22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4      NaN     27.0      NaN       26     25.0     24.0     23.0        22
#
#    11:30:00  12:30:00
# 0      20.0        21
# 1      19.0        20
# 2      25.0        25
# ...

# %%
# Typically, no of rows >>> no of columns -> long format dataset
# no of rows ~ or < no of columns ---> wide format dataset, rectangular dataset
# We cannot peform ML on wide format dataset

# %%
# Goal: Wide format dataset ---> Long format dataset

# %%
pd.melt(data, id_vars=['Date', 'Parameter', 'Drug_Name'])
# Out:
#            Date    Parameter                Drug_Name  variable  value
# 0    15-10-2020  Temperature  diltiazem hydrochloride   1:30:00   23.0
# 1    15-10-2020     Pressure  diltiazem hydrochloride   1:30:00   12.0
# 2    15-10-2020  Temperature      docetaxel injection   1:30:00    NaN
# 3    15-10-2020     Pressure      docetaxel injection   1:30:00    NaN
# 4    15-10-2020  Temperature   ketamine hydrochloride   1:30:00   24.0
# ..          ...          ...                      ...       ...    ...
# 211  17-10-2020     Pressure  diltiazem hydrochloride  12:30:00   14.0
# 212  17-10-2020  Temperature      docetaxel injection  12:30:00   23.0
# 213  17-10-2020     Pressure      docetaxel injection  12:30:00   28.0
# 214  17-10-2020  Temperature   ketamine hydrochloride  12:30:00   24.0
# 215  17-10-2020     Pressure   ketamine hydrochloride  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
data_melt = pd.melt(data, id_vars=['Date', 'Parameter', 'Drug_Name'],
      var_name="time",
      value_name="reading")
data_melt
# Out:
#            Date    Parameter                Drug_Name      time  reading
# 0    15-10-2020  Temperature  diltiazem hydrochloride   1:30:00     23.0
# 1    15-10-2020     Pressure  diltiazem hydrochloride   1:30:00     12.0
# 2    15-10-2020  Temperature      docetaxel injection   1:30:00      NaN
# 3    15-10-2020     Pressure      docetaxel injection   1:30:00      NaN
# 4    15-10-2020  Temperature   ketamine hydrochloride   1:30:00     24.0
# ..          ...          ...                      ...       ...      ...
# 211  17-10-2020     Pressure  diltiazem hydrochloride  12:30:00     14.0
# 212  17-10-2020  Temperature      docetaxel injection  12:30:00     23.0
# 213  17-10-2020     Pressure      docetaxel injection  12:30:00     28.0
# 214  17-10-2020  Temperature   ketamine hydrochloride  12:30:00     24.0
# 215  17-10-2020     Pressure   ketamine hydrochloride  12:30:00     15.0
#
# [216 rows x 5 columns]

# %%
# reverse the melting for the data_melt
data_melt.pivot(columns="time", values="reading", index=['Date','Drug_Name','Parameter']).reset_index()
# Out:
# time        Date                Drug_Name    Parameter  10:30:00  11:30:00  \
# 0     15-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 1     15-10-2020  diltiazem hydrochloride  Temperature      20.0      20.0
# 2     15-10-2020      docetaxel injection     Pressure      26.0      29.0
# 3     15-10-2020      docetaxel injection  Temperature      23.0      25.0
# 4     15-10-2020   ketamine hydrochloride     Pressure       9.0       9.0
# 5     15-10-2020   ketamine hydrochloride  Temperature      22.0      21.0
# 6     16-10-2020  diltiazem hydrochloride     Pressure      24.0       NaN
# 7     16-10-2020  diltiazem hydrochloride  Temperature      40.0       NaN
# 8     16-10-2020      docetaxel injection     Pressure      28.0      29.0
# 9     16-10-2020      docetaxel injection  Temperature      56.0      57.0
# 10    16-10-2020   ketamine hydrochloride     Pressure      16.0      17.0
# ...

# %%
# bring temperature and pressure into the same row
# columns - Parameter
# values - reading
data_tidy = data_melt.pivot(index=['Date','time', 'Drug_Name'],
                                        columns = 'Parameter',
                                        values='reading').reset_index()

data_tidy
# Out:
# Parameter        Date      time                Drug_Name  Pressure  \
# 0          15-10-2020  10:30:00  diltiazem hydrochloride      18.0
# 1          15-10-2020  10:30:00      docetaxel injection      26.0
# 2          15-10-2020  10:30:00   ketamine hydrochloride       9.0
# 3          15-10-2020  11:30:00  diltiazem hydrochloride      19.0
# 4          15-10-2020  11:30:00      docetaxel injection      29.0
# ..                ...       ...                      ...       ...
# 103        17-10-2020   8:30:00      docetaxel injection      26.0
# 104        17-10-2020   8:30:00   ketamine hydrochloride      11.0
# 105        17-10-2020   9:30:00  diltiazem hydrochloride       9.0
# 106        17-10-2020   9:30:00      docetaxel injection      27.0
# 107        17-10-2020   9:30:00   ketamine hydrochloride      12.0
#
# Parameter  Temperature
# 0                 20.0
# 1                 23.0
# 2                 22.0
# 3                 20.0
# 4                 25.0
# ...

# %%
data_tidy.columns
# Out:
# Index(['Date', 'time', 'Drug_Name', 'Pressure', 'Temperature'], dtype='object', name='Parameter')

# %%
data_tidy.columns.name = None
data_tidy
# Out:
#            Date      time                Drug_Name  Pressure  Temperature
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
# [108 rows x 5 columns]

# %%
data_tidy.head()
# Out:
#          Date      time                Drug_Name  Pressure  Temperature
# 0  15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1  15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2  15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3  15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4  15-10-2020  11:30:00      docetaxel injection      29.0         25.0

# %%
data_tidy.isnull().sum(axis=0) # no of missing valyes in every column
# Out:
# Date            0
# time            0
# Drug_Name       0
# Pressure       13
# Temperature    13
# dtype: int64

# %%
# None and NaN

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan) # so that it can be part of mathematical equstions
# Out:
# float

# %%
pd.Series([1, np.nan, 2, None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# dtype: float64

# %%
pd.Series(["1", "np.nan", "2", np.nan]) # everything in Python is an object
# Out:
# 0         1
# 1    np.nan
# 2         2
# 3       NaN
# dtype: object

# %%
# Handling Missing Values
# 1. Drop the rows/columns containing the
  # missing values [<5% missing]  - drop the missing data
  # extreme missing data [>40% missing] - drop the whole row/column
# 2. Fill the missing value with some estimate
  # Fill it with some constant - 0, 999999999999999999
  # Fill with some estimate - Mean and Median for numerical,  Mode (most freuently occuring value) for categorocal data

# %%
data.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
data.shape
# Out:
# (18, 15)

# %%
data.dropna().shape # by default dropna works with axis=0
# Out:
# (4, 15)

# %%
data.dropna(axis=0).shape
# Out:
# (4, 15)

# %%
data.dropna(axis=1).shape
# Out:
# (18, 6)

# %%
# Fill it with constant or an estimate
data
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
data.fillna(0)
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      0.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
data.fillna(999999)
# Out:
#           Date                Drug_Name    Parameter   1:30:00   2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature      23.0      22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure      12.0      13.0
# 2   15-10-2020      docetaxel injection  Temperature  999999.0      17.0
# 3   15-10-2020      docetaxel injection     Pressure  999999.0      22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature      24.0  999999.0
# 5   15-10-2020   ketamine hydrochloride     Pressure       8.0  999999.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature      34.0      35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure      18.0      19.0
# 8   16-10-2020      docetaxel injection  Temperature      46.0      47.0
# 9   16-10-2020      docetaxel injection     Pressure      23.0      24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature       8.0       9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure      12.0      12.0
# ...

# %%
data['2:30:00'] = data['2:30:00'].fillna(0)

# %%
# how to fillna with some estimate - mean

# %%
data["3:30:00"]
# Out:
# 0      NaN
# 1      NaN
# 2     18.0
# 3     22.0
# 4      NaN
# 5      NaN
# 6     36.0
# 7     20.0
# 8      NaN
# 9      NaN
# 10    10.0
# 11    13.0
# 12    19.0
# 13     4.0
# 14    14.0
# 15    22.0
# 16    15.0
# 17    10.0
# Name: 3:30:00, dtype: float64

# %%
data["3:30:00"].mean()
# Out:
# 16.916666666666668

# %%
data["3:30:00"].fillna(data["3:30:00"].mean())
# Out:
# 0     16.916667
# 1     16.916667
# 2     18.000000
# 3     22.000000
# 4     16.916667
# 5     16.916667
# 6     36.000000
# 7     20.000000
# 8     16.916667
# 9     16.916667
# 10    10.000000
# 11    13.000000
# 12    19.000000
# 13     4.000000
# 14    14.000000
# 15    22.000000
# 16    15.000000
# 17    10.000000
# Name: 3:30:00, dtype: float64

# %%
# Group by the drug name and calcukate their average temperarture and avg pressure

# %%
# aggregate
# filter
# apply

# %%
def temp_mean(x):
  x["Avg_Temperature"] = x["Temperature"].mean()
  return x

data_tidy = data_tidy.groupby("Drug_Name").apply(temp_mean)
data_tidy
# Out:
# <ipython-input-37-5d3b8ad4c954>:5: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_tidy = data_tidy.groupby("Drug_Name").apply(temp_mean)
#            Date      time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ...

# %%
data_tidy
# Out:
#            Date      time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#      Avg_Temperature
# 0          24.848485
# 1          30.387097
# ...

# %%
data_tidy["Temperature"].fillna(data_tidy["Avg_Temperature"])
# Out:
# 0      20.0
# 1      23.0
# 2      22.0
# 3      20.0
# 4      25.0
#        ...
# 103    19.0
# 104    20.0
# 105    13.0
# 106    20.0
# 107    21.0
# Name: Temperature, Length: 108, dtype: float64

# %%
def pr_mean(x):
  x['Pressure_avg'] = x['Pressure'].mean()
  return x
data_tidy=data_tidy.groupby(["Drug_Name"]).apply(pr_mean)
data_tidy['Pressure'].fillna(data_tidy["Pressure_avg"], inplace=True)
data_tidy
# Out:
# <ipython-input-40-df55c441df36>:4: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_tidy=data_tidy.groupby(["Drug_Name"]).apply(pr_mean)
#            Date      time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ...

# %% [markdown]
# #### Pandas cut
#
# 1. 1 to 6 - Detractors
# 2. 7 and 8 - Neutrals
# 3. 9 and 10 - Promoters

# %%
# numerical data into categorical

# %%
data_tidy["Temperature"].min(), data_tidy["Temperature"].max()
# Out:
# (8.0, 58.0)

# %%
temp_points = [5, 20, 35, 50, 60]
temp_labels = ["low", "medium", "high", "v high"]
pd.cut(data_tidy["Temperature"], bins=temp_points, labels=temp_labels)
# Out:
# 0         low
# 1      medium
# 2      medium
# 3         low
# 4      medium
#         ...
# 103       low
# 104       low
# 105       low
# 106       low
# 107    medium
# Name: Temperature, Length: 108, dtype: category
# Categories (4, object): ['low' < 'medium' < 'high' < 'v high']

# %%
data_tidy["Temperature"]
# Out:
# 0      20.0
# 1      23.0
# 2      22.0
# 3      20.0
# 4      25.0
#        ...
# 103    19.0
# 104    20.0
# 105    13.0
# 106    20.0
# 107    21.0
# Name: Temperature, Length: 108, dtype: float64

# %% [markdown]
# #### Data Visualisation-1

# %%
# Pending: String functions and datetime functions

# %%
data_tidy
# Out:
#            Date      time                Drug_Name  Pressure  Temperature  \
# 0    15-10-2020  10:30:00  diltiazem hydrochloride      18.0         20.0
# 1    15-10-2020  10:30:00      docetaxel injection      26.0         23.0
# 2    15-10-2020  10:30:00   ketamine hydrochloride       9.0         22.0
# 3    15-10-2020  11:30:00  diltiazem hydrochloride      19.0         20.0
# 4    15-10-2020  11:30:00      docetaxel injection      29.0         25.0
# ..          ...       ...                      ...       ...          ...
# 103  17-10-2020   8:30:00      docetaxel injection      26.0         19.0
# 104  17-10-2020   8:30:00   ketamine hydrochloride      11.0         20.0
# 105  17-10-2020   9:30:00  diltiazem hydrochloride       9.0         13.0
# 106  17-10-2020   9:30:00      docetaxel injection      27.0         20.0
# 107  17-10-2020   9:30:00   ketamine hydrochloride      12.0         21.0
#
#      Avg_Temperature  Pressure_avg
# 0          24.848485     15.424242
# ...

# %%
"hydrochloride" in data_tidy.loc[0, "Drug_Name"]
# Out:
# True

# %%
# python style of writing code - no vectorisation
output = []
for drug in data_tidy["Drug_Name"]:
  output.append(True if "hydrochloride" in drug else False)
print(output)
# Out:
# [True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True, True, False, True]

# %%
data_tidy["Drug_Name"].str.contains("hydrochloride")
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 103    False
# 104     True
# 105     True
# 106    False
# 107     True
# Name: Drug_Name, Length: 108, dtype: bool

# %% [markdown]
#  Series.str.function() helps you apply string methods on the whole series

# %% [markdown]
# #### Lets say, you want to perform some string operation and its not present in Pandas? How will you vectorise it?
#
# .apply() and pass the custom function that you write

# %%
data_tidy["Date"].str.split("-")
# Out:
# 0      [15, 10, 2020]
# 1      [15, 10, 2020]
# 2      [15, 10, 2020]
# 3      [15, 10, 2020]
# 4      [15, 10, 2020]
#             ...
# 103    [17, 10, 2020]
# 104    [17, 10, 2020]
# 105    [17, 10, 2020]
# 106    [17, 10, 2020]
# 107    [17, 10, 2020]
# Name: Date, Length: 108, dtype: object

# %% [markdown]
# Extract the year values from the date

# %%
data_tidy["Date"].str.split("-")[2]
# Out:
# ['15', '10', '2020']

# %%
data_tidy["Date"].str.split("-").apply(lambda x: x[-1]).astype("int")
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 103    2020
# 104    2020
# 105    2020
# 106    2020
# 107    2020
# Name: Date, Length: 108, dtype: int64

# %% [markdown]
# ### Datetime functions

# %%
data_tidy["timestamp"] = data_tidy["Date"] + " " + data_tidy["time"] # dtype = object

# %%
data_tidy.drop(["Date", "time"], axis=1, inplace=True)

# %%
data_tidy["timestamp"] = pd.to_datetime(data_tidy["timestamp"])

# %%
data_tidy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 0 to 107
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Drug_Name        108 non-null    object
#  1   Pressure         108 non-null    float64
#  2   Temperature      95 non-null     float64
#  3   Avg_Temperature  108 non-null    float64
#  4   Pressure_avg     108 non-null    float64
#  5   timestamp        108 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 10.0+ KB

# %%
data_tidy["timestamp"][0]
# Out:
# Timestamp('2020-10-15 10:30:00')

# %%
data_tidy["timestamp"][0].year
# Out:
# 2020

# %%
data_tidy["timestamp"][0].month
# Out:
# 10

# %%
data_tidy["timestamp"][0].day
# Out:
# 15

# %%
data_tidy["timestamp"][0].month_name()
# Out:
# 'October'

# %% [markdown]
# #### What about the series of timestamp objects?

# %%
data_tidy["timestamp"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 103    2020
# 104    2020
# 105    2020
# 106    2020
# 107    2020
# Name: timestamp, Length: 108, dtype: int64

# %%
data_tidy["timestamp"].dt.month_name()
# Out:
# 0      October
# 1      October
# 2      October
# 3      October
# 4      October
#         ...
# 103    October
# 104    October
# 105    October
# 106    October
# 107    October
# Name: timestamp, Length: 108, dtype: object

# %% [markdown]
# Doubts

# %%
"Anant" > "Gahan"
# Out:
# False

# %%
"01-01-2019" < "01-01-2020"
# Out:
# True
